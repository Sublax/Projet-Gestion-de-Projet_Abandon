# %%
import pandas as pd
import matplotlib.pyplot as plt
import country_converter as coco
import import_ipynb

# %%
df = pd.read_csv("../countries.csv")
df_transport = pd.read_csv("./public_transport.csv")

# %%
df_transport
# Out:
#           Entity Code  Year  \
# 0    Afghanistan  AFG  2020
# 1        Algeria  DZA  2020
# 2         Angola  AGO  2020
# 3      Argentina  ARG  2020
# 4      Australia  AUS  2020
# ..           ...  ...   ...
# 136    Venezuela  VEN  2020
# 137      Vietnam  VNM  2020
# 138        Yemen  YEM  2020
# 139       Zambia  ZMB  2020
# 140     Zimbabwe  ZWE  2020
#
#      Proportion of population that has convenient access to public transport
# 0                                            54.930000
# 1                                            40.566666
# 2                                            10.700000
# 3                                            57.547825
# 4                                            83.489480
# ..                                                 ...
# 136                                          42.465385
# 137                                          48.666668
# 138                                          41.019997
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country Code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 clean_dataworld(df_transport,"Transport")
#
# ...
